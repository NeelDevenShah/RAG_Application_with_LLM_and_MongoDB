# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import os
uri = os.environ.get('MONGO_URI')

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import pandas as pd
import pymongo

# %%
import pymongo
# Replace <connection_string> with the actual connection string provided by MongoDB Atlas
client = pymongo.MongoClient(uri)
db = client["flight_experiment"]
collection = db["Kaggle_CSV"]

# %%
df = pd.read_csv("Airline_review.csv")
df = df[:1000]

# %%
csv_data = df.to_dict("records")

# %%
df.head()
# Out:
#    Unnamed: 0   Airline Name Overall_Rating  \
# 0           0    AB Aviation              9
# 1           1    AB Aviation              1
# 2           2    AB Aviation              1
# 3           3  Adria Airways              1
# 4           4  Adria Airways              1
#
#                             Review_Title          Review Date  Verified  \
# 0                "pretty decent airline"   11th November 2019      True
# 1                   "Not a good airline"       25th June 2019      True
# 2         "flight was fortunately short"       25th June 2019      True
# 3    "I will never fly again with Adria"  28th September 2019     False
# 4  "it ruined our last days of holidays"  24th September 2019      True
#
#                                               Review       Aircraft  \
# 0    Moroni to Moheli. Turned out to be a pretty ...            NaN
# 1   Moroni to Anjouan. It is a very small airline...           E120
# 2    Anjouan to Dzaoudzi. A very small airline an...  Embraer E120
# 3    Please do a favor yourself and do not fly wi...            NaN
# 4   Do not book a flight with this airline! My fr...            NaN
#
#   Type Of Traveller      Seat Type                             Route  \
# 0      Solo Leisure  Economy Class                  Moroni to Moheli
# 1      Solo Leisure  Economy Class                 Moroni to Anjouan
# 2      Solo Leisure  Economy Class               Anjouan to Dzaoudzi
# 3      Solo Leisure  Economy Class             Frankfurt to Pristina
# 4    Couple Leisure  Economy Class  Sofia to Amsterdam via Ljubljana
#
#        Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0   November 2019           4.0                  5.0               4.0
# 1       June 2019           2.0                  2.0               1.0
# 2       June 2019           2.0                  1.0               1.0
# 3  September 2019           1.0                  1.0               NaN
# 4  September 2019           1.0                  1.0               1.0
#
#    Ground Service  Inflight Entertainment  Wifi & Connectivity  \
# 0             4.0                     NaN                  NaN
# 1             1.0                     NaN                  NaN
# 2             1.0                     NaN                  NaN
# 3             1.0                     NaN                  NaN
# 4             1.0                     1.0                  1.0
#
#    Value For Money Recommended
# 0              3.0         yes
# 1              2.0          no
# 2              2.0          no
# 3              1.0          no
# 4              1.0          no

# %%
collection.insert_many(csv_data)
# Out:
# InsertManyResult([ObjectId('6602f3d3c6a7587ff24e992d'), ObjectId('6602f3d3c6a7587ff24e992e'), ObjectId('6602f3d3c6a7587ff24e992f'), ObjectId('6602f3d3c6a7587ff24e9930'), ObjectId('6602f3d3c6a7587ff24e9931'), ObjectId('6602f3d3c6a7587ff24e9932'), ObjectId('6602f3d3c6a7587ff24e9933'), ObjectId('6602f3d3c6a7587ff24e9934'), ObjectId('6602f3d3c6a7587ff24e9935'), ObjectId('6602f3d3c6a7587ff24e9936'), ObjectId('6602f3d3c6a7587ff24e9937'), ObjectId('6602f3d3c6a7587ff24e9938'), ObjectId('6602f3d3c6a7587ff24e9939'), ObjectId('6602f3d3c6a7587ff24e993a'), ObjectId('6602f3d3c6a7587ff24e993b'), ObjectId('6602f3d3c6a7587ff24e993c'), ObjectId('6602f3d3c6a7587ff24e993d'), ObjectId('6602f3d3c6a7587ff24e993e'), ObjectId('6602f3d3c6a7587ff24e993f'), ObjectId('6602f3d3c6a7587ff24e9940'), ObjectId('6602f3d3c6a7587ff24e9941'), ObjectId('6602f3d3c6a7587ff24e9942'), ObjectId('6602f3d3c6a7587ff24e9943'), ObjectId('6602f3d3c6a7587ff24e9944'), ObjectId('6602f3d3c6a7587ff24e9945'), ObjectId('6602f3d3c6a7587ff24e9946'), ObjectId('6602f3d3c6a7587ff24e9947'), ObjectId('6602f3d3c6a7587ff24e9948'), ObjectId('6602f3d3c6a7587ff24e9949'), ObjectId('6602f3d3c6a7587ff24e994a'), ObjectId('6602f3d3c6a7587ff24e994b'), ObjectId('6602f3d3c6a7587ff24e994c'), ObjectId('6602f3d3c6a7587ff24e994d'), ObjectId('6602f3d3c6a7587ff24e994e'), ObjectId('6602f3d3c6a7587ff24e994f'), ObjectId('6602f3d3c6a7587ff24e9950'), ObjectId('6602f3d3c6a7587ff24e9951'), ObjectId('6602f3d3c6a7587ff24e9952'), ObjectId('6602f3d3c6a7587ff24e9953'), ObjectId('6602f3d3c6a7587ff24e9954'), ObjectId('6602f3d3c6a7587ff24e9955'), ObjectId('6602f3d3c6a7587ff24e9956'), ObjectId('6602f3d3c6a7587ff24e9957'), ObjectId('6602f3d3c6a7587ff24e9958'), ObjectId('6602f3d3c6a7587ff24e9959'), ObjectId('6602f3d3c6a7587ff24e995a'), ObjectId('6602f3d3c6a7587ff24e995b'), ObjectId('6602f3d3c6a7587ff24e995c'), ObjectId('6602f3d3c6a7587ff24e995d'), ObjectId('6602f3d3c6a7587ff24e995e'), ObjectId('6602f3d3c6a7587ff24e995f'), ObjectId('6602f3d3c6a7587ff24e9960'), ObjectId('6602f3d3c6a7587ff24e9961'), ObjectId('6602f3d3c6a7587ff24e9962'), ObjectId('6602f3d3c6a7587ff24e9963'), ObjectId('6602f3d3c6a7587ff24e9964'), ObjectId('6602f3d3c6a7587ff24e9965'), ObjectId('6602f3d3c6a7587ff24e9966'), ObjectId('6602f3d3c6a7587ff24e9967'), ObjectId('6602f3d3c6a7587ff24e9968'), ObjectId('6602f3d3c6a7587ff24e9969'), ObjectId('6602f3d3c6a7587ff24e996a'), ObjectId('6602f3d3c6a7587ff24e996b'), ObjectId('6602f3d3c6a7587ff24e996c'), ObjectId('6602f3d3c6a7587ff24e996d'), ObjectId('6602f3d3c6a7587ff24e996e'), ObjectId('6602f3d3c6a7587ff24e996f'), ObjectId('6602f3d3c6a7587ff24e9970'), ObjectId('6602f3d3c6a7587ff24e9971'), ObjectId('6602f3d3c6a7587ff24e9972'), ObjectId('6602f3d3c6a7587ff24e9973'), ObjectId('6602f3d3c6a7587ff24e9974'), ObjectId('6602f3d3c6a7587ff24e9975'), ObjectId('6602f3d3c6a7587ff24e9976'), ObjectId('6602f3d3c6a7587ff24e9977'), ObjectId('6602f3d3c6a7587ff24e9978'), ObjectId('6602f3d3c6a7587ff24e9979'), ObjectId('6602f3d3c6a7587ff24e997a'), ObjectId('6602f3d3c6a7587ff24e997b'), ObjectId('6602f3d3c6a7587ff24e997c'), ObjectId('6602f3d3c6a7587ff24e997d'), ObjectId('6602f3d3c6a7587ff24e997e'), ObjectId('6602f3d3c6a7587ff24e997f'), ObjectId('6602f3d3c6a7587ff24e9980'), ObjectId('6602f3d3c6a7587ff24e9981'), ObjectId('6602f3d3c6a7587ff24e9982'), ObjectId('6602f3d3c6a7587ff24e9983'), ObjectId('6602f3d3c6a7587ff24e9984'), ObjectId('6602f3d3c6a7587ff24e9985'), ObjectId('6602f3d3c6a7587ff24e9986'), ObjectId('6602f3d3c6a7587ff24e9987'), ObjectId('6602f3d3c6a7587ff24e9988'), ObjectId('6602f3d3c6a7587ff24e9989'), ObjectId('6602f3d3c6a7587ff24e998a'), ObjectId('6602f3d3c6a7587ff24e998b'), ObjectId('6602f3d3c6a7587ff24e998c'), ObjectId('6602f3d3c6a7587ff24e998d'), ObjectId('6602f3d3c6a7587ff24e998e'), ObjectId('6602f3d3c6a7587ff24e998f'), ObjectId('6602f3d3c6a7587ff24e9990'), ObjectId('6602f3d3c6a7587ff24e9991'), ObjectId('6602f3d3c6a7587ff24e9992'), ObjectId('6602f3d3c6a7587ff24e9993'), ObjectId('6602f3d3c6a7587ff24e9994'), ObjectId('6602f3d3c6a7587ff24e ...
