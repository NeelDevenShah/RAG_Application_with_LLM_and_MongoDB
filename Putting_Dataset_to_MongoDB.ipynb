# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import os
uri = os.environ.get('MONGO_URI')

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import pandas as pd
import pymongo

# %%
import pymongo
# Replace <connection_string> with the actual connection string provided by MongoDB Atlas
client = pymongo.MongoClient(uri)
db = client["flight_experiment"]
collection = db["Kaggle_CSV"]

# %%
df = pd.read_csv("Airline_review.csv")
df = df[:1000]

# %%
csv_data = df.to_dict("records")

# %%
df.head()
# Out:
#    Unnamed: 0   Airline Name Overall_Rating  \
# 0           0    AB Aviation              9
# 1           1    AB Aviation              1
# 2           2    AB Aviation              1
# 3           3  Adria Airways              1
# 4           4  Adria Airways              1
#
#                             Review_Title          Review Date  Verified  \
# 0                "pretty decent airline"   11th November 2019      True
# 1                   "Not a good airline"       25th June 2019      True
# 2         "flight was fortunately short"       25th June 2019      True
# 3    "I will never fly again with Adria"  28th September 2019     False
# 4  "it ruined our last days of holidays"  24th September 2019      True
#
#                                               Review       Aircraft  \
# 0    Moroni to Moheli. Turned out to be a pretty ...            NaN
# 1   Moroni to Anjouan. It is a very small airline...           E120
# 2    Anjouan to Dzaoudzi. A very small airline an...  Embraer E120
# 3    Please do a favor yourself and do not fly wi...            NaN
# 4   Do not book a flight with this airline! My fr...            NaN
#
#   Type Of Traveller      Seat Type                             Route  \
# 0      Solo Leisure  Economy Class                  Moroni to Moheli
# 1      Solo Leisure  Economy Class                 Moroni to Anjouan
# 2      Solo Leisure  Economy Class               Anjouan to Dzaoudzi
# 3      Solo Leisure  Economy Class             Frankfurt to Pristina
# 4    Couple Leisure  Economy Class  Sofia to Amsterdam via Ljubljana
#
#        Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0   November 2019           4.0                  5.0               4.0
# 1       June 2019           2.0                  2.0               1.0
# 2       June 2019           2.0                  1.0               1.0
# 3  September 2019           1.0                  1.0               NaN
# 4  September 2019           1.0                  1.0               1.0
#
#    Ground Service  Inflight Entertainment  Wifi & Connectivity  \
# 0             4.0                     NaN                  NaN
# 1             1.0                     NaN                  NaN
# 2             1.0                     NaN                  NaN
# 3             1.0                     NaN                  NaN
# 4             1.0                     1.0                  1.0
#
#    Value For Money Recommended
# 0              3.0         yes
# 1              2.0          no
# 2              2.0          no
# 3              1.0          no
# 4              1.0          no

# %%
collection.insert_many(csv_data)
# Out:
# InsertManyResult([ObjectId('66016ba93bb6c88554f35a61'), ObjectId('66016ba93bb6c88554f35a62'), ObjectId('66016ba93bb6c88554f35a63'), ObjectId('66016ba93bb6c88554f35a64'), ObjectId('66016ba93bb6c88554f35a65'), ObjectId('66016ba93bb6c88554f35a66'), ObjectId('66016ba93bb6c88554f35a67'), ObjectId('66016ba93bb6c88554f35a68'), ObjectId('66016ba93bb6c88554f35a69'), ObjectId('66016ba93bb6c88554f35a6a'), ObjectId('66016ba93bb6c88554f35a6b'), ObjectId('66016ba93bb6c88554f35a6c'), ObjectId('66016ba93bb6c88554f35a6d'), ObjectId('66016ba93bb6c88554f35a6e'), ObjectId('66016ba93bb6c88554f35a6f'), ObjectId('66016ba93bb6c88554f35a70'), ObjectId('66016ba93bb6c88554f35a71'), ObjectId('66016ba93bb6c88554f35a72'), ObjectId('66016ba93bb6c88554f35a73'), ObjectId('66016ba93bb6c88554f35a74'), ObjectId('66016ba93bb6c88554f35a75'), ObjectId('66016ba93bb6c88554f35a76'), ObjectId('66016ba93bb6c88554f35a77'), ObjectId('66016ba93bb6c88554f35a78'), ObjectId('66016ba93bb6c88554f35a79'), ObjectId('66016ba93bb6c88554f35a7a'), ObjectId('66016ba93bb6c88554f35a7b'), ObjectId('66016ba93bb6c88554f35a7c'), ObjectId('66016ba93bb6c88554f35a7d'), ObjectId('66016ba93bb6c88554f35a7e'), ObjectId('66016ba93bb6c88554f35a7f'), ObjectId('66016ba93bb6c88554f35a80'), ObjectId('66016ba93bb6c88554f35a81'), ObjectId('66016ba93bb6c88554f35a82'), ObjectId('66016ba93bb6c88554f35a83'), ObjectId('66016ba93bb6c88554f35a84'), ObjectId('66016ba93bb6c88554f35a85'), ObjectId('66016ba93bb6c88554f35a86'), ObjectId('66016ba93bb6c88554f35a87'), ObjectId('66016ba93bb6c88554f35a88'), ObjectId('66016ba93bb6c88554f35a89'), ObjectId('66016ba93bb6c88554f35a8a'), ObjectId('66016ba93bb6c88554f35a8b'), ObjectId('66016ba93bb6c88554f35a8c'), ObjectId('66016ba93bb6c88554f35a8d'), ObjectId('66016ba93bb6c88554f35a8e'), ObjectId('66016ba93bb6c88554f35a8f'), ObjectId('66016ba93bb6c88554f35a90'), ObjectId('66016ba93bb6c88554f35a91'), ObjectId('66016ba93bb6c88554f35a92'), ObjectId('66016ba93bb6c88554f35a93'), ObjectId('66016ba93bb6c88554f35a94'), ObjectId('66016ba93bb6c88554f35a95'), ObjectId('66016ba93bb6c88554f35a96'), ObjectId('66016ba93bb6c88554f35a97'), ObjectId('66016ba93bb6c88554f35a98'), ObjectId('66016ba93bb6c88554f35a99'), ObjectId('66016ba93bb6c88554f35a9a'), ObjectId('66016ba93bb6c88554f35a9b'), ObjectId('66016ba93bb6c88554f35a9c'), ObjectId('66016ba93bb6c88554f35a9d'), ObjectId('66016ba93bb6c88554f35a9e'), ObjectId('66016ba93bb6c88554f35a9f'), ObjectId('66016ba93bb6c88554f35aa0'), ObjectId('66016ba93bb6c88554f35aa1'), ObjectId('66016ba93bb6c88554f35aa2'), ObjectId('66016ba93bb6c88554f35aa3'), ObjectId('66016ba93bb6c88554f35aa4'), ObjectId('66016ba93bb6c88554f35aa5'), ObjectId('66016ba93bb6c88554f35aa6'), ObjectId('66016ba93bb6c88554f35aa7'), ObjectId('66016ba93bb6c88554f35aa8'), ObjectId('66016ba93bb6c88554f35aa9'), ObjectId('66016ba93bb6c88554f35aaa'), ObjectId('66016ba93bb6c88554f35aab'), ObjectId('66016ba93bb6c88554f35aac'), ObjectId('66016ba93bb6c88554f35aad'), ObjectId('66016ba93bb6c88554f35aae'), ObjectId('66016ba93bb6c88554f35aaf'), ObjectId('66016ba93bb6c88554f35ab0'), ObjectId('66016ba93bb6c88554f35ab1'), ObjectId('66016ba93bb6c88554f35ab2'), ObjectId('66016ba93bb6c88554f35ab3'), ObjectId('66016ba93bb6c88554f35ab4'), ObjectId('66016ba93bb6c88554f35ab5'), ObjectId('66016ba93bb6c88554f35ab6'), ObjectId('66016ba93bb6c88554f35ab7'), ObjectId('66016ba93bb6c88554f35ab8'), ObjectId('66016ba93bb6c88554f35ab9'), ObjectId('66016ba93bb6c88554f35aba'), ObjectId('66016ba93bb6c88554f35abb'), ObjectId('66016ba93bb6c88554f35abc'), ObjectId('66016ba93bb6c88554f35abd'), ObjectId('66016ba93bb6c88554f35abe'), ObjectId('66016ba93bb6c88554f35abf'), ObjectId('66016ba93bb6c88554f35ac0'), ObjectId('66016ba93bb6c88554f35ac1'), ObjectId('66016ba93bb6c88554f35ac2'), ObjectId('66016ba93bb6c88554f35ac3'), ObjectId('66016ba93bb6c88554f35ac4'), ObjectId('66016ba93bb6c88554f35ac5'), ObjectId('66016ba93bb6c88554f35ac6'), ObjectId('66016ba93bb6c88554f35ac7'), ObjectId('66016ba93bb6c88554f35ac8'), ObjectId('66016ba93bb6c88554f3 ...
