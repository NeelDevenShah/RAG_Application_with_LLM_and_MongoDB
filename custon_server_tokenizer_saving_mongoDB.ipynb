# %% [markdown]
# <h1>In this, I have used the server, Which contains the tokenizer from hugging face, Tokenizer used is : sentence-transformers/all-MiniLM-L6-v2</h1>
# While using the api interface of hugging face there is the limit of using, that's why i have made the endpoint named server under Tokenizer_Server directory which can be deployed on the cloud service and the tokenizer service can be utilized, For experimental purpose this server was hosted on azure.

# %%
import pymongo
import os
import requests
import json
from bson import ObjectId

# %%
# Connect to MongoDB
client = pymongo.MongoClient(os.environ.get("MONGO_URI"))
db = client[os.environ.get("DATABASE")]
collection = db[os.environ.get("COLLECTION")]

# %%
cluster_data = collection.find()

# %%
import requests
import json
from bson import ObjectId  # Add this import statement

# Iterate over the data and add the embedding to each document
for data in cluster_data:
    url = f"{os.environ.get('SERVER_URL')}preprocess"
    headers = {"Content-Type": "application/json"}

    # Convert ObjectId to string
    data["_id"] = str(data["_id"])
    print(url)
    response = requests.post(url, headers=headers, data=json.dumps(data))

    if response.status_code == 200:
        print("API call successful")
        print(response.json())
    else:
        print("API call failed")

    break
# Out:
# http://20.193.130.111:5000/preprocess
# API call successful
# {'embeddings': [[-0.05696325749158859, 0.0032082933466881514, -0.02948366291821003, -0.01365156564861536, -0.0028031093534082174, -0.01357368566095829, 0.1063414067029953, -0.01756170205771923, -0.00978885032236576, -0.03651345893740654, -0.03326572850346565, -0.09919249266386032, -0.023757612332701683, 0.03275580704212189, -0.10431268811225891, 0.005024605896323919, -0.058300696313381195, -0.03676050901412964, -0.05827375128865242, -0.015012465417385101, -0.03994646668434143, 0.019378796219825745, -0.07507798820734024, -0.016533100977540016, -0.015290118753910065, -0.052957747131586075, 0.021351657807826996, 0.06336923688650131, 0.0022368277423083782, -0.07510841637849808, 0.07156025618314743, 0.02789073809981346, 0.07143018394708633, -0.03748870640993118, 0.11003735661506653, 0.018876750022172928, -0.008750010281801224, -0.07042206823825836, 0.051144421100616455, 0.02170781046152115, -0.008841406553983688, -0.026153812184929848, 0.03900519013404846, 0.0309771578758955, 0.006926063913851976, 0.019448962062597275, -0.06450413912534714, 0.0043715438805520535, 0.013935200870037079, -0.004095097538083792, -0.039364151656627655, 0.017074856907129288, -0.059613291174173355, 0.032659225165843964, -0.028038721531629562, 0.011972272768616676, -0.05613137409090996, 0.017987672239542007, 0.04496967792510986, 0.004243389703333378, 0.11710292845964432, -0.033473901450634, 0.026768658310174942, -0.03341612219810486, -0.015700777992606163, -0.0366700105369091, -0.03859765827655792, -0.09084763377904892, -0.021636221557855606, -0.049016136676073074, -0.020544975996017456, 0.10458757728338242, -0.05664217844605446, -0.008942816406488419, 0.03976039960980415, -0.04172099381685257, -0.06013919413089752, -0.046217840164899826, -0.01424745935946703, -0.008172707632184029, -0.06376242637634277, -0.03373640775680542, -0.018911685794591904, 0.04244016855955124, 0.010550460778176785, -0.03684377670288086, -0.003726539434865117, 0.03993826359510422, 0.02518112026154995, 0.006711370777338743, 0.015990829095244408, 0.047643523663282394, -0.016682730987668037, -0.04450186714529991, -0.0023658510763198137, 0.006059345323592424, 0.11234759539365768, -0.006757098715752363, -0.06155148148536682, 0.1511395275592804, -0.009327893145382404, -0.015649685636162758, -0.03215310350060463, 0.03636998310685158, 0.03060566447675228, 0.00935511477291584, -0.018597720190882683, 0.09138977527618408, -0.0631512925028801, 0.0055916327983140945, -0.11633436381816864, 0.027765754610300064, -0.08972024917602539, 0.029525134712457657, 0.09197548031806946, 0.06828395277261734, -0.0027095871046185493, 0.06369146704673767, 0.09591394662857056, 0.015057685784995556, 0.10342571884393692, -0.040414661169052124, -0.0461684986948967, -0.020916270092129707, -0.14532774686813354, -0.055381596088409424, -0.014246683567762375, 1.2668423106982752e-32, -0.009473449550569057, 0.03259784355759621, -0.026144493371248245, -0.026409965008497238, -0.031017964705824852, 0.073078453540802, -0.021509381011128426, -0.03275784105062485, 0.028390295803546906, 0.020816471427679062, -0.08452276140451431, -0.010862658731639385, 0.0006201196811161935, 0.055264975875616074, -0.0007749535143375397, 0.02956634946167469, 0.027789171785116196, 0.07483280450105667, -0.09200193732976913, -0.033187612891197205, -0.020775431767106056, -0.032784368842840195, -0.035396888852119446, 0.024027463048696518, -0.011972644366323948, 0.10456416010856628, -0.01951024681329727, -0.06702007353305817, 0.051265764981508255, 0.0032764438074082136, 0.02312939055263996, -0.004951637703925371, -0.07264544814825058, -0.035020384937524796, -0.018843989819288254, 0.08374674618244171, -0.04879666119813919, -0.04492125287652016, -0.0433712862432003, -0.017330393195152283, 0.017386581748723984, 0.022012298926711082, -0.11065057665109634, -0.0323239266872406, -0.05055011063814163, -0.03486549109220505, 0.09152955561876297, -0.005080814473330975, 0.026725279167294502, 0.001809480250813067, -0.0947384312748909, 0.031017936766147614, -0.140755 ...

# %%
import requests
import json
from bson import ObjectId  # Add this import statement

# Iterate over the data and add the embedding to each document
for data in cluster_data:
    url = f"{os.environ.get('SERVER_URL')}preprocess"
    headers = {"Content-Type": "application/json"}
    print(data)
    # Convert ObjectId to string
    data["_id"] = str(data["_id"])
    response = requests.post(url, headers=headers, data=json.dumps(data))

    if response.status_code == 200:
        # Storing the embeddings into the database
        print(collection.update_one({"_id": ObjectId(data["_id"])}, {"$set": {"embedding": response.json()}}))
        print(response.json())
    else:
        print("API call failed")
# Out:
# {'_id': ObjectId('6600612b87f42350f791c9d1'), 'Unnamed: 0': 15, 'Airline Name': 'Adria Airways', 'Overall_Rating': '1', 'Review_Title': '"Flight was very comfortable"', 'Review Date': '4th May 2018', 'Verified': True, 'Review': '  Frankfurt to Ljubljana. Flight was very comfortable, professional crew. The monitors above passengers provide informations about flight (speed, altitude, temperature, time to landing, etc.)', 'Aircraft': nan, 'Type Of Traveller': 'Business', 'Seat Type': 'Economy Class', 'Route': 'Frankfurt to Ljubljana', 'Date Flown': 'April 2018', 'Seat Comfort': 5.0, 'Cabin Staff Service': 5.0, 'Food & Beverages': 5.0, 'Ground Service': 5.0, 'Inflight Entertainment': nan, 'Wifi & Connectivity': nan, 'Value For Money': 5.0, 'Recommended': 'yes'}
# <class 'str'>
# -------------
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000001c9'), 'opTime': {'ts': Timestamp(1711316058, 25), 't': 457}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1711316058, 25), 'signature': {'hash': b'\xcb\x18\xfa@L#4&\xa2\xf7zV\x00\xad\xa9s\x80\xc2\xfa\xdf', 'keyId': 7286340459213881346}}, 'operationTime': Timestamp(1711316058, 25), 'updatedExisting': True}, acknowledged=True)
